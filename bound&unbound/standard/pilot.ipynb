# %%
import numpy as np
import matplotlib.pyplot as plt
import plumed
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import math
import MDAnalysis as mda
import string

# %% [markdown]
# # Cluster analysis for the 8 configurations

# %%
from sklearn.cluster import KMeans
from MDAnalysis.analysis.rms import RMSD

# %%
rmsd = plumed.read_as_pandas("rmsd.dat")
rtp = plumed.read_as_pandas("rtp_coord.dat")
coord_numb = plumed.read_as_pandas("coord_number_45.dat")
# Out:
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1108/3328687685.py:1: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rmsd = plumed.read_as_pandas("rmsd.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1108/3328687685.py:2: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp = plumed.read_as_pandas("rtp_coord.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1108/3328687685.py:3: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_numb = plumed.read_as_pandas("coord_number_45.dat")

# %%
# Select the element below a threshold 
rmsd_cut = []
dist_cut = []
time_cut = []
labels_sim_cut = []
for i in range(len(rtp)):
    if rtp["rho"][i] < 1.2:
        rmsd_cut.append(rmsd["rmsd"][i])
        dist_cut.append(rtp["rho"][i])


# Create the "data" needed for clustering
data = []
for i in range(len(rmsd_cut)):
    data.append([rmsd_cut[i], dist_cut[i]])

data = np.array(data)

# %%
# Specify the number of clusters (K)
num_clusters = 8

# Perform K-means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(data)

# Get cluster assignments and cluster centers
labels = kmeans.labels_
# The centers will be important in the remaining part of the notebook
centers = kmeans.cluster_centers_

# Plot the data points and cluster centers
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='YlOrBr', marker='o', s=5, label='Data Points')
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', label='Cluster Centers')
plt.title(f'K-means clustering with K={num_clusters}')
plt.xlabel('RMSD of the backbone atoms in the pocket [nm]')
plt.ylabel('Distance O-Ca2+ [nm]')
plt.legend(loc='upper left')
plt.grid()
plt.savefig("k_clusters.png")

# %%
# Ora la domanda è: come posso rintracciare le configurazioni a partire dai centri?

# Assign each frame of your trajectory to the cluster whose center it is closest to. 
# This step helps categorize the trajectory frames into distinct clusters.

# Compute cluster centers and predict cluster index for each sample

# Take the labels of the previously computed clusters 
labels = kmeans.fit_predict(data)

structures = []

# Identify representative configurations for each cluster
for cluster_label in range(8):

    # I get the positions of the frames belonging to the clusters.
    # cluster_indices changes dimensions during at each iteration of the loop
    cluster_indices = np.where(labels == cluster_label)[0]

    dist = [2]
    min = 1
    for i in range(1, len(cluster_indices)):
        # I take the square of the distances
        # I loop over the set of indices associated to a given cluster
        dist.append((data[cluster_indices][i][0] - centers[cluster_label][0])**2 + (data[cluster_indices][i][1] - centers[cluster_label][1])**2)
        if min > dist[i]:
            min = dist[i]
            ref = cluster_indices[i]

    structures.append(ref)
    #structures.append(np.argmin(dist))

# %%
centers
# Out:
# array([[0.0477097 , 0.03212486],
#        [0.09343   , 0.77817832],
#        [0.08064443, 0.29722347],
#        [0.08922605, 1.00919283],
#        [0.06609779, 0.15748935],
#        [0.05226312, 0.07764499],
#        [0.09202038, 0.40241915],
#        [0.09693506, 0.54512386]])

# %%
# List of the frames that have to be dumped from the fitted trajectory with 
# water on the cluster 
structures

#gmx_mpi trjconv -dump 9699 -s md_Meta.tpr -f traj_comp.xtc -o frame_9699.gro
# Out:
# [5850, 10224, 9699, 10295, 3237, 2932, 9018, 10105]

# %% [markdown]
# # Analyzing the unbiased simulations

# %%
rtp_0 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.0.dat")
rtp_1 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.1.dat")
rtp_2 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.2.dat")
rtp_3 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.3.dat")
rtp_4 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.4.dat")
rtp_5 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.5.dat")
rtp_6 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.6.dat")
rtp_7 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.7.dat")

coord_0 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.0.dat")
coord_1 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.1.dat")
coord_2 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.2.dat")
coord_3 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.3.dat")
coord_4 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.4.dat")
coord_5 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.5.dat")
coord_6 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.6.dat")
coord_7 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.7.dat")
# Out:
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1108/522312255.py:1: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_0 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.0.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1108/522312255.py:2: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_1 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.1.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1108/522312255.py:3: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_2 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.2.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1108/522312255.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_3 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.3.dat")
# ...

# %%
# Wc stands for "Water-coordinated"
rtps_Wc = np.concatenate((rtp_1["rho"], rtp_2["rho"], rtp_6["rho"], rtp_7["rho"]), axis=None)
coords_Wc = np.concatenate((coord_1["c"], coord_2["c"], coord_6["c"], coord_7["c"]), axis=None)

# %%
# Select the element below a threshold 
rtps_cut_Wc = []
coords_cut_Wc = []

for i in range(len(rtps_Wc)):
    if rtps_Wc[i] < 0.8 and coords_Wc[i] > 5:
        rtps_cut_Wc.append(rtps_Wc[i])
        coords_cut_Wc.append(coords_Wc[i])

# %%
import os
import matplotlib.animation as animation
import matplotlib.image as mpimg
from matplotlib.offsetbox import (OffsetImage, AnnotationBbox)

# %%
# Define number of bins
bins = 50  # Adjust the number of bins based on your preference

# Compute 2D histogram
hist, xedges, yedges = np.histogram2d(rtps_cut_Wc, coords_cut_Wc, bins=bins, density=True)

# Plot filled contour plot
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.contourf(xedges[:-1], yedges[:-1], hist.T, cmap='YlOrBr', vmin=-0.4)
#vmin=-100,vmax=800
plt.colorbar(label='Density')  # Add color bar indicating density

# Add contour lines
levels = np.linspace(hist.min(), hist.max(), 10)  # Adjust number of contour levels as needed
plt.contour(xedges[:-1], yedges[:-1], hist.T, levels=levels, colors='black', linewidths=0.5)

plt.xlabel(r'Distance $d_{Ox}$')
plt.ylabel(r'Coordination number $C_N$')
plt.title(r'Water-coordinated Ca$^{2+}$ states')

image = mpimg.imread("Wc_state.png")
# Insert the image in a small portion of the plot 
sub_axes = plt.axes([0.45, 0.5, 0.35, 0.35])  
# plt.axes((left, bottom, width, height))
sub_axes.imshow(image, extent=[1.2, 1.5, 1.2, 1.5])
# Hide the axes
sub_axes.xaxis.set_tick_params(labelbottom=False)
sub_axes.yaxis.set_tick_params(labelleft=False)
# Hide X and Y axes tick marks
sub_axes.set_xticks([])
sub_axes.set_yticks([]) 

plt.savefig("Wc_states.png")

# %%
# Oxc stands for "Oxygen-coordinated"
rtps_Oxc = np.concatenate((rtp_0["rho"], rtp_4["rho"], rtp_5["rho"]), axis=None)
coords_Oxc = np.concatenate((coord_0["c"], coord_4["c"], coord_5["c"]), axis=None)

# %%
# Select the element below a threshold 
rtps_cut_Oxc = []
coords_cut_Oxc = []

for i in range(len(rtps_Oxc)):
    if rtps_Oxc[i] < 0.8 and coords_Oxc[i] > 5:
        rtps_cut_Oxc.append(rtps_Oxc[i])
        coords_cut_Oxc.append(coords_Oxc[i])

# %%
# Define number of bins
bins = 50  # Adjust the number of bins based on your preference

# Compute 2D histogram
hist, xedges, yedges = np.histogram2d(rtps_cut_Oxc, coords_cut_Oxc, bins=bins, density=True)

# Plot filled contour plot
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.contourf(xedges[:-1], yedges[:-1], hist.T, cmap='YlOrBr', vmin=-5)
#vmin=-100,vmax=800
plt.colorbar(label='Density')  # Add color bar indicating density

# Add contour lines
levels = np.linspace(hist.min(), hist.max(), 10)  # Adjust number of contour levels as needed
plt.contour(xedges[:-1], yedges[:-1], hist.T, levels=levels, colors='black', linewidths=0.5)
plt.xlabel(r'Distance $d_{Ox}$')
plt.ylabel(r'Coordination number $C_N$')
plt.title(r'Oxygen-coordinated Ca$^{2+}$ states')


image = mpimg.imread("Oxc_state.png")
# Insert the image in a small portion of the plot 
sub_axes = plt.axes([0.45, 0.5, 0.35, 0.35])  
# plt.axes((left, bottom, width, height))
sub_axes.imshow(image, extent=[1.2, 1.5, 1.2, 1.5])
# Hide the axes
sub_axes.xaxis.set_tick_params(labelbottom=False)
sub_axes.yaxis.set_tick_params(labelleft=False)
# Hide X and Y axes tick marks
sub_axes.set_xticks([])
sub_axes.set_yticks([]) 

plt.savefig("Oxc_states.png")

# %% [markdown]
# # RMSD and Cn of the pocket

# %%
all_0 = plumed.read_as_pandas("all/ALL0.dat")
all_1 = plumed.read_as_pandas("all/ALL1.dat")
all_2 = plumed.read_as_pandas("all/ALL2.dat")
all_3 = plumed.read_as_pandas("all/ALL3.dat")
all_4 = plumed.read_as_pandas("all/ALL4.dat")
all_5 = plumed.read_as_pandas("all/ALL5.dat")
all_6 = plumed.read_as_pandas("all/ALL6.dat")
all_7 = plumed.read_as_pandas("all/ALL7.dat")
# Out:
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1915/1112747087.py:1: UserWarning: cannot load PLUMED instance, conversions will not be available
#   all_0 = plumed.read_as_pandas("all/ALL0.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1915/1112747087.py:2: UserWarning: cannot load PLUMED instance, conversions will not be available
#   all_1 = plumed.read_as_pandas("all/ALL1.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1915/1112747087.py:3: UserWarning: cannot load PLUMED instance, conversions will not be available
#   all_2 = plumed.read_as_pandas("all/ALL2.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1915/1112747087.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   all_3 = plumed.read_as_pandas("all/ALL3.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_1915/1112747087.py:5: UserWarning: cannot load PLUMED instance, conversions will not be available
# ...

# %%
all_rmsd = np.concatenate((all_0["rmsd"], all_1["rmsd"], all_2["rmsd"], all_4["rmsd"], all_5["rmsd"], all_6["rmsd"], all_7["rmsd"]), axis=None)
all_c = np.concatenate((all_0["c"], all_1["c"], all_2["c"], all_4["c"], all_5["c"], all_6["c"], all_7["c"]), axis=None)

# %%
# Define number of bins
bins = 50  # Adjust the number of bins based on your preference

# Compute 2D histogram
hist, xedges, yedges = np.histogram2d(all_rmsd, all_c, bins=bins, density=True)

# Plot filled contour plot
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.contourf(xedges[:-1], yedges[:-1], hist.T, cmap='YlOrBr', vmin=-2)
#vmin=-100,vmax=800
plt.colorbar(label='Density')  # Add color bar indicating density

# Add contour lines
levels = np.linspace(hist.min(), hist.max(), 10)  # Adjust number of contour levels as needed
plt.contour(xedges[:-1], yedges[:-1], hist.T, levels=levels, colors='black', linewidths=0.5)

plt.xlabel(r'RMSD of the backbone atoms in the pocket [nm]')
plt.ylabel(r'Coordination number $C_N$')
plt.title(r'RMSD vs $C_N$')


image = mpimg.imread("Oxc_state.png")
# Insert the image in a small portion of the plot 
sub_axes = plt.axes([0.28, 0.64, 0.25, 0.25])  
# plt.axes((left, bottom, width, height))
sub_axes.imshow(image, extent=[1.2, 1.5, 1.2, 1.5])
# Hide the axes
sub_axes.xaxis.set_tick_params(labelbottom=False)
sub_axes.yaxis.set_tick_params(labelleft=False)
# Hide X and Y axes tick marks
sub_axes.set_xticks([])
sub_axes.set_yticks([]) 


image = mpimg.imread("Wc_state.png")
# Insert the image in a small portion of the plot 
sub_axes = plt.axes([0.55, 0.11, 0.25, 0.25])  
# plt.axes((left, bottom, width, height))
sub_axes.imshow(image, extent=[1.2, 1.5, 1.2, 1.5])
# Hide the axes
sub_axes.xaxis.set_tick_params(labelbottom=False)
sub_axes.yaxis.set_tick_params(labelleft=False)
# Hide X and Y axes tick marks
sub_axes.set_xticks([])
sub_axes.set_yticks([]) 

plt.savefig("RMSD_Cn.png")
