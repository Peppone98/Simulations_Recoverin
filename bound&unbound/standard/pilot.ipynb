# %%
import numpy as np
import matplotlib.pyplot as plt
import plumed
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import math
import MDAnalysis as mda
import string

# %% [markdown]
# # Cluster analysis for the 8 configurations

# %%
from sklearn.cluster import KMeans
from MDAnalysis.analysis.rms import RMSD

# %%
rmsd = plumed.read_as_pandas("rmsd.dat")
rtp = plumed.read_as_pandas("rtp_coord.dat")
coord_numb = plumed.read_as_pandas("coord_number_45.dat")
# Out:
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_2147/3328687685.py:1: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rmsd = plumed.read_as_pandas("rmsd.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_2147/3328687685.py:2: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp = plumed.read_as_pandas("rtp_coord.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_2147/3328687685.py:3: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_numb = plumed.read_as_pandas("coord_number_45.dat")

# %%
# Select the element below a threshold 
rmsd_cut = []
dist_cut = []
time_cut = []
labels_sim_cut = []
for i in range(len(rtp)):
    if rtp["rho"][i] < 1.2:
        rmsd_cut.append(rmsd["rmsd"][i])
        dist_cut.append(rtp["rho"][i])


# Create the "data" needed for clustering
data = []
for i in range(len(rmsd_cut)):
    data.append([rmsd_cut[i], dist_cut[i]])

data = np.array(data)

# %%
# Specify the number of clusters (K)
num_clusters = 8

# Perform K-means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(data)

# Get cluster assignments and cluster centers
labels = kmeans.labels_
# The centers will be important in the remaining part of the notebook
centers = kmeans.cluster_centers_

# Plot the data points and cluster centers
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', marker='o', s=5, label='Data Points')
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', label='Cluster Centers')
plt.title(f'K-means clustering with K={num_clusters}')
plt.xlabel('RMSD of the backbone atoms in the pocket [nm]')
plt.ylabel('Distance O-Ca2+ [nm]')
plt.legend(loc='upper left')
plt.grid()
plt.savefig("k_clusters.png")

# %%
# Ora la domanda è: come posso rintracciare le configurazioni a partire dai centri?

# Assign each frame of your trajectory to the cluster whose center it is closest to. 
# This step helps categorize the trajectory frames into distinct clusters.

# Compute cluster centers and predict cluster index for each sample

# Take the labels of the previously computed clusters 
labels = kmeans.fit_predict(data)

structures = []

# Identify representative configurations for each cluster
for cluster_label in range(8):

    # I get the positions of the frames belonging to the clusters.
    # cluster_indices changes dimensions during at each iteration of the loop
    cluster_indices = np.where(labels == cluster_label)[0]

    dist = [2]
    min = 1
    for i in range(1, len(cluster_indices)):
        # I take the square of the distances
        # I loop over the set of indices associated to a given cluster
        dist.append((data[cluster_indices][i][0] - centers[cluster_label][0])**2 + (data[cluster_indices][i][1] - centers[cluster_label][1])**2)
        if min > dist[i]:
            min = dist[i]
            ref = cluster_indices[i]

    structures.append(ref)
    #structures.append(np.argmin(dist))

# %%
centers
# Out:
# array([[0.0477097 , 0.03212486],
#        [0.09343   , 0.77817832],
#        [0.08064443, 0.29722347],
#        [0.08922605, 1.00919283],
#        [0.06609779, 0.15748935],
#        [0.05226312, 0.07764499],
#        [0.09202038, 0.40241915],
#        [0.09693506, 0.54512386]])

# %%
# List of the frames that have to be dumped from the fitted trajectory with 
# water on the cluster 
structures

#gmx_mpi trjconv -dump 9699 -s md_Meta.tpr -f traj_comp.xtc -o frame_9699.gro
# Out:
# [5850, 10224, 9699, 10295, 3237, 2932, 9018, 10105]

# %% [markdown]
# # Analyzing the unbiased simulations

# %%
rtp_0 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.0.dat")
rtp_1 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.1.dat")
rtp_2 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.2.dat")
rtp_3 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.3.dat")
rtp_4 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.4.dat")
rtp_5 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.5.dat")
rtp_6 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.6.dat")
rtp_7 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.7.dat")

coord_0 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.0.dat")
coord_1 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.1.dat")
coord_2 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.2.dat")
coord_3 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.3.dat")
coord_4 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.4.dat")
coord_5 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.5.dat")
coord_6 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.6.dat")
coord_7 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.7.dat")
# Out:
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:1: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_0 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.0.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:2: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_1 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.1.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:3: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_2 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.2.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_3 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.3.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:5: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_4 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.4.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:6: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_5 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.5.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:7: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_6 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.6.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:8: UserWarning: cannot load PLUMED instance, conversions will not be available
#   rtp_7 = plumed.read_as_pandas("unbiased_analysis/rtps/rtp_coord.7.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:10: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_0 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.0.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:11: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_1 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.1.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:12: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_2 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.2.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:13: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_3 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.3.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:14: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_4 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.4.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:15: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_5 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.5.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:16: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_6 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.6.dat")
# /var/folders/hn/315sv5754l3bwzn1_mtrpscc0000gn/T/ipykernel_7132/522312255.py:17: UserWarning: cannot load PLUMED instance, conversions will not be available
#   coord_7 = plumed.read_as_pandas("unbiased_analysis/coords/coord_number_45.7.dat")

# %%
rtps = np.concatenate((rtp_0["rho"], rtp_1["rho"], rtp_2["rho"], rtp_3["rho"], rtp_4["rho"], rtp_5["rho"], rtp_6["rho"], rtp_7["rho"]), axis=None)
coords = np.concatenate((coord_0["c"], coord_1["c"], coord_2["c"], coord_3["c"], coord_4["c"], coord_5["c"], coord_6["c"], coord_7["c"]), axis=None)

# %%
# Select the element below a threshold 
rtps_cut = []
coords_cut = []

for i in range(len(rtps)):
    if rtps[i] < 0.8 and coords[i] > 10:
        rtps_cut.append(rtps[i])
        coords_cut.append(coords[i])

# %%
# Define number of bins
bins = 100  # Adjust the number of bins based on your preference

# Compute 2D histogram
hist, xedges, yedges = np.histogram2d(rtps_cut, coords_cut, bins=bins, density=False)

# Plot filled contour plot
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.contourf(xedges[:-1], yedges[:-1], hist.T, cmap='viridis', vmin=-100,vmax=800)
plt.colorbar(label='Density')  # Add color bar indicating density

# Add contour lines
levels = np.linspace(hist.min(), hist.max(), 10)  # Adjust number of contour levels as needed
plt.contour(xedges[:-1], yedges[:-1], hist.T, levels=levels, colors='black', linewidths=0.5)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Contour Plot with Contour Lines')
plt.show()

# %%
plt.scatter(rtps, coords)
